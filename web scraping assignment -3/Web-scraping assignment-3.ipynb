# %%
#import libraries
import selenium
import requests
from selenium import webdriver
import pandas as pd
import time
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# 1. Write a python program which searches all the product under a particular product from www.amazon.in.
# The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search
# for guitars

# %%
#lets first connect to webdriver
driver=webdriver.Chrome(r'C:\Users\91964\Desktop\nazia\chromedriver_win32\chromedriver.exe')
url='https://www.amazon.in'
driver.get(url)

# %%
user_input=input(" Enter the product :  ")
# Out:
#  Enter the product :  Guiter

# %%
# finding web element for search job bar using id
search_product=driver.find_element_by_id("twotabsearchtextbox" )

# %%
search_product.send_keys(user_input)

# %%
search_btn=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")

# %%
search_btn.click()

# %%
#driver.close()

# %% [raw]
# 2. In the above question, now scrape the following details of each product listed in first 3 pages of your
# search results and save it in a data frame and csv. In case if any product has less than 3 pages in search
# results then scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
urls = []
start=0
end=3
for page in range(start,end):
    
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')    
    for i in url:
        urls.append(i.get_attribute("href")) 
        
    nxt_button=driver.find_element_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    nxt_button.click()
    
Brand_name = []   
Product_name = []
Price = []
Return_Exchange = []
expected_delivery = []
Availability = [] 

for url in urls:
    driver.get(url)
    time.sleep(2)
    
    
    try:
        brand = driver.find_element_by_xpath('//a[@id="bylineInfo"]')      
        Brand_name.append(brand.text)
    except NoSuchElementException:
        Brand.append('--')  
        
        
    try:
        name = driver.find_element_by_id('productTitle')      
        Product_name.append(name.text)
    except NoSuchElementException:
        Name.append('--')
        
        
    try:
        price = driver.find_element_by_xpath('//td[@class="a-span12"]')  
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('--')
        
    try:
        return_exchange = driver.find_element_by_xpath('//a[@class="a-size-small a-link-normal a-text-normal"]')  
        Return_Exchange.append(return_exchange.text)
    except NoSuchElementException:
        Return_Exchange.append('--')
        
        
    try:
        available= driver.find_element_by_xpath('//span[@class="a-size-medium a-color-success"]')  
        Availability.append(available.text)
    except NoSuchElementException:
        Availability.append('--')
        
        
    try:
        expected_delivery= driver.find_element_by_xpath('//span[@class="a-color-error"]')  
        Expected_delivery.append(expected_delivery.text)
    except NoSuchElementException:
        Expected_delivery.append('--')
        
        

df= pd.DataFrame({'Brand_name':Brand_name,
                  'Product_Name':Product_Name,
                  'Price':Price,
                  'Return_Exchange':Return_Exchange,
                  'Expected_delivery':Expected_delivery,
                  'Availability':Availability,
                  'urls':urls})

df

# %% [raw]
# # saving in csv file
# pd.DataFrame(df).to_csv('data.csv',index=0)

# %% [raw]
# # 3. Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
#lets first connect to webdriver
driver=webdriver.Chrome(r'C:\Users\91964\Desktop\nazia\chromedriver_win32\chromedriver.exe')
driver.get('https://images.google.com')

# %%
# finding web element for search bar using id
search_bar=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')

# %%
search_bar.send_keys('fruits')

# %%
search_btn=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span')

# %%
search_btn.click()

# %%
for _ in range(500):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
img_urls=[]
img_tag=driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

for image in img_tag:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 11:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\91964\Desktop\FlipRobo\images\fruits"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\91964\Desktop\nazia\chromedriver_win32\chromedriver.exe')
driver.get('https://images.google.com')
search_bar=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_bar.send_keys('Cars')
search_btn=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span')
search_btn.click()

# %%
img_urls=[]
img_tag=driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

for image in img_tag:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 11:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\91964\Desktop\FlipRobo\images\fruits"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\91964\Desktop\nazia\chromedriver_win32\chromedriver.exe')
driver.get('https://images.google.com')
search_bar=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_bar.send_keys('machine learning')
search_btn=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span')
search_btn.click()

img_urls=[]
img_tag=driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

for image in img_tag:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 11:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\91964\Desktop\FlipRobo\images\fruits"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\91964\Desktop\nazia\chromedriver_win32\chromedriver.exe')
driver.get('https://images.google.com')
search_bar=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_bar.send_keys('cakes')
search_btn=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span')
search_btn.click()

img_urls=[]
img_tag=driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

for image in img_tag:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 11:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\91964\Desktop\FlipRobo\images\fruits"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\91964\Desktop\nazia\chromedriver_win32\chromedriver.exe')
driver.get('https://images.google.com')
search_bar=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_bar.send_keys('guiter')
search_btn=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span')
search_btn.click()

img_urls=[]
img_tag=driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

for image in img_tag:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 11:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\91964\Desktop\FlipRobo\images\fruits"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
driver.close()

# %% [raw]
# 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be
# scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
driver=webdriver.Chrome(r'C:\Users\91964\Desktop\nazia\chromedriver_win32\chromedriver.exe')
driver.get('https://www.flipkart.com')

# %%
# finding web element for search bar using id
search_bar=driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')

# %%
search_bar.send_keys('smartphone')

# %%
search_btn=driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')

# %%
search_btn.click()

# %%
Brand_name=[]
phonename=[]
color=[]
rom=[]

tag=driver.find_elements_by_xpath('//div[@class="_4rR01T"]')

for i in tag:
        Brand_name.append(i.text.split(' ')[0])
        phonename.append(i.text.split(' ')[1])
        color.append(i.text.split('(')[1].split(',')[0])
        rom.append(i.text.split('(')[1].split(',')[1])
        
len(Brand_name),len(phonename),len(color),len(rom)
# Out:
# (24, 24, 24, 24)

# %%
ram=[]
primary_camera=[]
secondary_camera=[]
display_size=[]
cam_tag=driver.find_elements_by_xpath('//div[@class="fMghEO"]')
battery=[]

for i in cam_tag:
        ram.append(i.text.split('|')[0])
        primary_camera.append(i.text.split('\n')[2].split('|')[0])
        secondary_camera.append(i.text.split('\n')[2].split('|')[1])
        display_size.append(i.text.split('\n')[1])
        battery.append(i.text.split('\n')[3])

len(ram),len(primary_camera),len(secondary_camera),len(display_size),len(battery)
# Out:
# (24, 24, 24, 24, 24)

# %%
price=[]
price_tag=driver.find_elements_by_xpath('//div[@class="_30jeq3 _1_WHN1"]')
for i in price_tag:
    
    price.append(i.text)
len(price)
# Out:
# 24

# %%
url=[]
for i in driver.find_elements_by_xpath('//a[@class="_1fQZEK"]'):
    url.append(i.get_attribute("href"))
    
len(url)
# Out:
# 24

# %%
dataframe=pd.DataFrame({'Brand_name':Brand_name,
            'phonename':phonename,
             'color':color,
            'rom':rom,
            'ram':ram,
            'primary_camera':primary_camera,
            'secondary_camera':secondary_camera,
            'display_size': display_size,
            'battery':battery,       
            'price':price,
            'url':url
           })   

dataframe
# Out:
#    Brand_name phonename         color       rom        ram  \
# 0      realme     Narzo    Mint Green    32 GB)  2 GB RAM
# 1      realme     Narzo  Carbon Black    32 GB)  2 GB RAM
# 2      realme     Narzo    Mint Green    64 GB)  4 GB RAM
# 3     SAMSUNG    Galaxy     Sea Green    64 GB)  4 GB RAM
# 4      realme     Narzo  Oxygen Green    64 GB)  4 GB RAM
# 5      realme     Narzo   Oxygen Blue   128 GB)  4 GB RAM
# 6      realme     Narzo  Carbon Black    64 GB)  4 GB RAM
# 7      realme     Narzo   Oxygen Blue    64 GB)  4 GB RAM
# 8      realme      C21Y    Cross Blue    32 GB)  3 GB RAM
# 9      realme      C21Y   Cross Black    64 GB)  4 GB RAM
# 10     realme      C21Y    Cross Blue    64 GB)  4 GB RAM
# 11     realme      C25Y    Metal Grey   128 GB)  4 GB RAM
# 12     realme        8i  Space Purple   128 GB)  6 GB RAM
# 13     realme      C21Y   Cross Black    32 GB)  3 GB RAM
# 14    SAMSUNG    Galaxy      Sky Blue    64 GB)  4 GB RAM
# ...

# %%
# saving in csv file
pd.DataFrame(dataframe).to_csv('data1.csv',index=0)

# %% [raw]
# # 5.Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
# import regex(regular expression)
import re

# %%
#lets first connect to webdriver
driver=webdriver.Chrome(r'C:\Users\91964\Desktop\nazia\chromedriver_win32\chromedriver.exe')
driver.get('https://www.google.co.in/maps')

# %%
# finding web element for search job bar using id
search_city=driver.find_element_by_id("searchboxinput" )

# %%
search_city.send_keys('kolkata')

# %%
search_btn=driver.find_element_by_xpath('/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]/button')

# %%
search_btn.click()

# %%
url=driver.current_url
try:
    latti_longi=re.findall(r'@(.*)data',url)         
except:
    print('exception:', e)

latti_longi
# Out:
# ['22.6757521,88.0495301,10z/']

# %%
lattitude_longitude=[]
tag=driver.find_elements_by_xpath('//button[@class="nGhxh-tv6Bve GaSlwc-uhFGfc-WsjYwc-zfKixb-UacCoe"]')
for i in tag:
    lattitude_longitude.append(i.text)
lattitude_longitude
# Out:
# ['22.547712, 88.350281']

# %%
driver.close()

# %% [raw]
# # 6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in.

# %%
#lets first connect to webdriver
driver=webdriver.Chrome(r'C:\Users\91964\Desktop\nazia\chromedriver_win32\chromedriver.exe')
url=('https://trak.in/india-startup-funding-investment-2015/')
driver.get(url)
time.sleep(2)

# %%
# Defining Variables
slno=[]# empty list
date=[]# empty list
startupname=[]# empty list
industry=[]# empty list
subvertical=[]# empty list
city=[]# empty list
investors=[]# empty list
investment_type=[]# empty list
amount=[]# empty list

sl_tag=driver.find_elements_by_xpath('//td[@class="column-1"]')
date_tag=driver.find_elements_by_xpath('//td[@class="column-2"]')
start_tag=driver.find_elements_by_xpath('//td[@class="column-3"]')
industry_tag=driver.find_elements_by_xpath('//td[@class="column-4"]')
sub_tag=driver.find_elements_by_xpath('//td[@class="column-5"]')
city_tag=driver.find_elements_by_xpath('//td[@class="column-6"]')
investor_tag=driver.find_elements_by_xpath('//td[@class="column-7"]')
type_tag=driver.find_elements_by_xpath('//td[@class="column-8"]')
amount_tag=driver.find_elements_by_xpath('//td[@class="column-9"]')
for j in sl_tag:
     slno.append(j.text)
for j in date_tag:
     date.append(j.text)
for i in start_tag:
    startupname.append(i.text)   
for j in industry_tag:
     industry.append(j.text)
for j in sub_tag:
     subvertical.append(j.text)
for j in city_tag:
     city.append(j.text)
for j in investor_tag:
     investors.append(j.text)
for j in type_tag:
     investment_type.append(j.text)
for j in amount_tag:
     amount.append(j.text)
                
# Make data frame of funding deals:    

Funding_deals=pd.DataFrame({})
Funding_deals['Sl.no']=slno[:24]
Funding_deals['Date']=date[:24]
Funding_deals['StartupName']=startupname[:24]
Funding_deals['Industry']=industry[:24]
Funding_deals['Subvertical']=subvertical[:24]
Funding_deals['City']=city[:24]
Funding_deals['Investors']=investors[:24]
Funding_deals['Investment_Type']=investment_type[:24]
Funding_deals['Amount']=amount[:24]
Funding_deals
# Out:
#    Sl.no        Date      StartupName              Industry  \
# 0      1  01/04/2021           BYJU’S              Edu-tech
# 1      2  05/04/2021           Meesho            E-commerce
# 2      3  14/04/2021           Swiggy  Online Food Delivery
# 3      4  07/04/2021            Groww               FinTech
# 4      5  14/04/2021          Beldara            E-commerce
# 5      1  04/03/2021        DealShare            E-commerce
# 6      2  31/03/2021         Uniphore            Technology
# 7      3  30/03/2021            Dunzo            E-commerce
# 8      4  30/03/2021           BYJU’S              Edu-tech
# 9      5  23/03/2021      SkilloVilla              Edu-tech
# 10     6  25/03/2021         CityMall            E-commerce
# 11     7  26/03/2021            DotPe               FinTech
# 12     1  11/02/2021         Doubtnut              Edu Tech
# 13     2  22/02/2021           Zomato           Hospitality
# 14     3  19/02/2021        Fingerlix           Hospitality
# ...

# %%
driver.close()

# %% [raw]
# 7. Write a program to scrap all the available details of best gaming laptops from digit.in

# %%
#lets first connect to webdriver
driver=webdriver.Chrome(r'C:\Users\91964\Desktop\nazia\chromedriver_win32\chromedriver.exe')
url='https://www.digit.in'
driver.get(url)

# %%
gaming=driver.find_element_by_xpath("/html/body/div[2]/div/div[4]/ul/li[4]/a")
gaming.click()

# %%
time.sleep(2)
laptop=driver.find_element_by_xpath('/html/body/div[4]/div/div/div[2]/div[5]/div[1]/div/button[2]')
laptop.click()

# %%
best_gaming=driver.find_element_by_xpath("/html/body/div[4]/div/div/div[3]/div[2]/ul/li[1]/a")
driver.get(best_gaming.get_attribute('href'))

# %%
product_name = []
name=driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
for i in name:
    product_name.append(i.text)

Price = []
price=driver.find_elements_by_xpath('//table[@id="summtable"]//tr//td[3]')
for i in price:
    Price.append(i.text)

# %%
OS = []
os=driver.find_elements_by_xpath('//div[@class="value"]')
for i in os:
    OS.append(i.text)
OS=OS[0::4]
len(OS)
# Out:
# 10

# %%
display=[]
dis=driver.find_elements_by_xpath('//div[@class="value"]')
for i in dis:
    display.append(i.text)
display=display[1::4]
len(display)
# Out:
# 10

# %%
processor=[]
pro=driver.find_elements_by_xpath('//div[@class="value"]')
for i in pro:
    processor.append(i.text)
processor=processor[2::4]
len(processor)
# Out:
# 10

# %%
memory=[]
tag_=driver.find_elements_by_xpath('//div[@class="value"]')
for i in tag_:
    memory.append(i.text)
memory=memory[3::4]
len(memory)
# Out:
# 10

# %%
weight=[]
tag2=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]')
for i in tag2:
    weight.append(i.text)

# %%
dimension=[]
tag3=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
for i in tag3:
    dimension.append(i.text)

graphics_processor=[]
tag1=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[9]/td[3]")
for i in tag1:
    graphics_processor.append(i.text)

# %%
df=pd.DataFrame({"Product_Name":product_name,
                "Price":Price,
                 "OS":OS,
                 "Display":display,
                 "Processor":processor,
                 "Memory":memory,
                 "Weight":weight,
                 "Dimension":dimension,
                 "Graphics_processor":graphics_processor
                })
df
# Out:
#                   Product_Name      Price               OS  \
# 0                 ACER NITRO 5  ₹ 129,990       WINDOWS 10
# 1              MSI STEALTH 15M  ₹ 134,990       WINDOWS 10
# 2       ASUS ROG STRIX SCAR 15  ₹ 268,990       WINDOWS 10
# 3        ALIENWARE AREA 51M R2  ₹ 342,989  WINDOWS 10 HOME
# 4             ALIENWARE M15 R3  ₹ 319,990  WINDOWS 10 HOME
# 5       ASUS ROG STRIX SCAR 15  ₹ 215,990  WINDOWS 10 HOME
# 6            ASUS ZEPHYRUS G14  ₹ 164,990  WINDOWS 10 HOME
# 7             LENOVO LEGION 5I   ₹ 76,988   WINDOWS 10 PRO
# 8     ASUS ROG ZEPHYRUS DUO 15  ₹ 185,000       WINDOWS 10
# 9  ACER ASPIRE 7 GAMING LAPTOP   ₹ 57,990  WINDOWS 10 HOME
#
#                Display                                   Processor  \
# 0  15.6" (1920 X 1080)             AMD RYZEN 9 OCTA CORE | 2.4 GHZ
# 1  15.6" (1920 X 1080)        INTEL CORE I7 11TH GEN - 11375H | NA
# 2  15.6" (2560 X 1440)    AMD RYZEN 9 OCTA CORE - 5900HX | 3.3 GHZ
# ...

# %%
driver.close()

# %% [raw]
# # 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
#lets first connect to webdriver
driver=webdriver.Chrome(r'C:\Users\91964\Desktop\nazia\chromedriver_win32\chromedriver.exe')
driver.get('https://www.forbes.com/billionaires/')

# %%
# Defining Variables
Rank=[]
rank_tag=driver.find_elements_by_xpath('//div[@class="rank"]')

for j in rank_tag:
     Rank.append(j.text)
len(Rank)
# Out:
# 200

# %%
Name=[]
name_tag=driver.find_elements_by_xpath('//div[@class="personName"]')

for j in name_tag:
     Name.append(j.text)
len(Name)
# Out:
# 200

# %%
Net_worth=[]
net_tag=driver.find_elements_by_xpath('//div[@class="netWorth"]')

for j in net_tag:
     Net_worth.append(j.text)
len(Net_worth)
# Out:
# 200

# %%
Age=[]
age_tag=driver.find_elements_by_xpath('//div[@class="age"]')

for j in age_tag:
     Age.append(j.text)
len(Age)
# Out:
# 200

# %%
citizen=[]
citizen_tag=driver.find_elements_by_xpath('//div[@class="countryOfCitizenship"]')

for j in citizen_tag:
     citizen.append(j.text)
len(citizen)
# Out:
# 200

# %%
source=[]
source_tag=driver.find_elements_by_xpath('//div[@class="source-column"]')

for j in source_tag:
     source.append(j.text)
len(source)
# Out:
# 200

# %%
industry=[]
industry_tag=driver.find_elements_by_xpath('//div[@class="category"]')

for j in industry_tag:
     industry.append(j.text)
len(industry)
# Out:
# 200

# %%
Billionaires=pd.DataFrame({'Rank':Rank,'Name':Name,
                           'Net_worth':Net_worth,
                           'Age':Age,
                           'Citizen':citizen,
                           'Source':source,
                           'Industry': industry
                          })
Billionaires
# Out:
#      Rank                      Name Net_worth Age        Citizen  \
# 0      1.                Jeff Bezos    $177 B      United States
# 1      2.                 Elon Musk    $151 B      United States
# 2      3.  Bernard Arnault & family    $150 B             France
# 3      4.                Bill Gates    $124 B      United States
# 4      5.           Mark Zuckerberg     $97 B      United States
# ..    ...                       ...       ...  ..            ...
# 195  195.           Harry Triguboff   $11.2 B          Australia
# 196  197.     Leonid Fedun & family   $11.1 B             Russia
# 197  197.                 Eyal Ofer   $11.1 B             Israel
# 198  197.              Evan Spiegel   $11.1 B      United States
# 199  200.     Luis Carlos Sarmiento     $11 B           Colombia
#
#                     Source               Industry
# 0                   Amazon             Technology
# 1            Tesla, SpaceX             Automotive
# ...

# %% [raw]
# # 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video

# %%
#lets first connect to webdriver
driver=webdriver.Chrome(r'C:\Users\91964\Desktop\nazia\chromedriver_win32\chromedriver.exe')
url='https://www.youtube.com'
driver.get(url)

# %%
search_bar=driver.find_element_by_xpath('/html/body/ytd-app/div/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/form/div[1]/div[1]/input')

# %%
search_bar.send_keys("Dance with Deepti")

# %%
search_btn=driver.find_element_by_id("search-icon-legacy")

# %%
search_btn.click()

# %%
video_link=driver.find_element_by_xpath("//yt-formatted-string[@class ='style-scope ytd-video-renderer']")

# %%
video_link.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
comments=[]
comments_tag=driver.find_elements_by_id("content-text")
for i in comments_tag:
    try:
        comments.append(i.text)
    except:
        comments.append('--')
len(comments)
# Out:
# 1460

# %%
upvotes=[]
likes=[]
upvote = driver.find_elements_by_xpath("//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in upvote:
    upvotes.append(i.text)
    
for i in range(1,len(upvotes),2):
    likes.append(upvotes[i]) 
len(likes)
# Out:
# 1460

# %%
time=[]

time_tag=driver.find_elements_by_xpath('//yt-formatted-string[@class="published-time-text above-comment style-scope ytd-comment-renderer"]')
for i in time_tag:
    time.append(i.text)
len(time)
# Out:
# 1460

# %%
df=pd.DataFrame({'Comments':comments[:500],
                 'likes':likes[:500],
                 'Time': time[:500]
                  })
df
# Out:
#                                               Comments likes  \
# 0    Thanks a looot... ❤\nI lost 5kgs 😍\nThank you ...   194
# 1    Loved these workouts. Much effective and effic...    16
# 2    I started my weight loss journey yesterday and...    64
# 3    The workout was really awesome, first time I c...    13
# 4    My current favorite workout! The steps are so ...    22
# ..                                                 ...   ...
# 495                     Monday-Day 1\nDay 2 done\n.\n.     3
# 496           thanks mam it was very enjoyfull session
# 497  Hi! Today is my first day. Only for fitness I ...
# 498   Burnt 170 calories in this session. Thank You! 😘    11
# 499  Awesome learned exercise as well as dance than...
#
#                       Time
# 0              1 month ago
# 1             2 months ago
# 2             2 months ago
# 3              1 month ago
# 4    3 months ago (edited)
# ..                     ...
# 495  3 months ago (edited)
# ...

# %%
driver.close()

# %% [raw]
# 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews,
# overall reviews, privates from price, dorms from price, facilities and property description

# %%
#lets first connect to webdriver
driver=webdriver.Chrome(r'C:\Users\91964\Desktop\nazia\chromedriver_win32\chromedriver.exe')
url='https://www.hostelworld.com/st/hostels/europe/england/london'
driver.get(url)

# %%
btn=driver.find_element_by_xpath('/html/body/div[3]/div/div/div/header/div[2]/div[2]/div[4]/div/div/div/div[3]/div/a')

# %% [raw]
# btn.click()

# %%
name=[]

while(True):
    name_=driver.find_elements_by_xpath('//h2[@class="title title-6"]')
    for i in name_:
        name.append(i.text) 

    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break

# %%
distance=[]
while(True):
    dis_=driver.find_elements_by_xpath('//span[@class="description"]')
    for i in dis_:
        distance.append(i.text)
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
# Out:
# 22

# %%
overall_review=[]
while(True):
    reviewtag=driver.find_elements_by_xpath('//div[@class="keyword"]/span')
    for i in reviewtag:
        overall_review.append(i.text)
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
# Out:
# 22

# %%
total_review=[]
while(True):
    review_tag=driver.find_elements_by_xpath('//div[@class="reviews"]')
    for i in review_tag:
        total_review.append(i.text)
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
# Out:
# 22

# %%
privates_price=[]
while(True):
    privates_tag=driver.find_elements_by_xpath('//div[@class="price-col"]')
    for i in privates_tag:
        privates_price.append(i.text.split('\n')[-1])
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
        
privates_price=privates_price[0: :2 ]
# Out:
# 22

# %%
dorm_price=[]
while(True):
    tag=driver.find_elements_by_xpath('//div[@class="price-col"]')
    for i in tag:
        dorm_price.append(i.text.split('\n')[-1])
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
dorm_price=dorm_price[1: :2 ]
# Out:
# 22

# %%
facility=[]
while(True):
    facilitytag=driver.find_elements_by_xpath('//div[@class="facilities-label facilities"]')
    for i in facilitytag:
        facility.append(i.text)
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
# Out:
# 22

# %%
property_des=[]
url=[]
for i in driver.find_elements_by_xpath('//h2[@class="title title-6"]'):
    url.append(i.get_attribute('href')) 
    

    try:
        pro_des = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/section/div[6]/div/div[2]/div[2]/div/div[2]')
        property_des.append(pd.text)
    except NoSuchElementException:
        property_des.append("No Description")  

(pro_des)
# Out:
# []

# %%
ratings=[]
url=[]
for i in driver.find_elements_by_xpath('//h2[@class="title title-6"]'):
    url.append(i.get_attribute('href'))
    
    rate_=driver.find_elements_by_xpath("//div[@class='score orange big']")
    for i in rate_:
        try:
            ratings.append(i.text)
        except NoSuchElementException:
            ratings.append("No Rating")

# %%
london_hostel=pd.DataFrame({'Hostel_Name':name,
                           'Distance':distance,
                           'Ratings':ratings[:22],
                           'Overall_review':overall_review,
                           'Total_review':total_review,
                           'privates_price':privates_price,
                           'dorm_price':dorm_price,
                            'Facility':facility,
                            #'Pro_des':pro_des 
                           }) 
london_hostel
# Out:
#                                Hostel_Name  \
# 0                              Barry House
# 1                          Marble Arch Inn
# 2                                The Dover
# 3   Best Western Boltons London Kensington
# 4                            Elmwood Hotel
# 5                    Hyde Park Court Hotel
# 6                 Budget London Apartments
# 7                            Fairway Hotel
# 8                       Golders Park Hotel
# 9                          Wellesley Hotel
# 10                         Paramount Hotel
# 11                         St George Hotel
# 12                   Belgrave Hotel London
# 13                        Aron Guest House
# 14                            Beaconsfield
# 15                            Victor Hotel
# 16                               Kip Hotel
# 17                             Green Rooms
# 18                        23 Matheson Road
# 19                        Park Hotel Essex
# 20                         Cranbrook Hotel
# ...

# %%
driver.close()
