# %%
# Importing Libraries
import numpy as np
import pandas as pd
import selenium
import time
# importing selenium webdriver
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException

#Importing requests
import requests

# importing regex
import re

import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
#lets first connect to webdriver
driver=webdriver.Chrome('chromedriver.exe')

# Opening the homepage 
Url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(Url)

# %%
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
views=[]

# %%
#scraping Rank
rank=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[1]')
for i in rank:
    if i.text is None:
        Rank.append('--')
    else:
        Rank.append(i.text)

# %%
len(Rank)
# Out:
# 49

# %%
#scraping Rank
name=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[2]')
for i in name:
    if i.text is None:
        Name.append('--')
    else:
        Name.append(i.text)

# %%
len(Name)
# Out:
# 49

# %%
#scraping Artist
artist=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[3]')
for i in artist:
    if i.text is None:
        Artist.append('--')
    else:
        Artist.append(i.text)

# %%
len(Artist)
# Out:
# 49

# %%
#scraping upload date
upload=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[5]')
for i in upload:
    if i.text is None:
        Upload_date.append('--')
    else:
        Upload_date.append(i.text)

# %%
len(Upload_date)
# Out:
# 49

# %%
#scraping views
view=driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[4]')
for i in view:
    if i.text is None:
        views.append('--')
    else:
        views.append(i.text)

# %%
len(views)
# Out:
# 49

# %%
# making DataFrame
video=pd.DataFrame({'Rank':Rank[:30],
                    'Name':Name[:30],
                    'Artist':Artist[:30],
                    'Upload_date':Upload_date[:30],
                     'views':views[:30]
                     })
video
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[21]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[22]
# 8    9.                "Phonics Song with Two Words"[23]
# 9   10.                                "Uptown Funk"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                             "Dame Tu Cosita"[30]
# 12  13.                          "Wheels on the Bus"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %%
driver.close()

# %% [raw]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code

# %%
#lets first connect to webdriver
driver=webdriver.Chrome('chromedriver.exe')

# Opening the homepage 
Url = "https://www.bcci.tv/"
driver.get(Url)

# %%
international_fixture=driver.find_element_by_xpath("/html/body/nav/div/div[2]/ul[1]/li[2]/a")
driver.get(international_fixture.get_attribute('href'))

# %% [raw]
# #getting international button
# driver.find_element_by_xpath('/html/body/nav/div/div[2]/ul[1]/li[2]').click()

# %%
# more fixure
more_fixure=driver.find_element_by_xpath("//button[@class='match-btn btn-red d-flex align-items-center justify-content-center mx-auto mt-3']")
more_fixure.click()

# %%
title=[]
series=[]
place=[]
date=[]
time=[]

# %%
name=driver.find_elements_by_xpath('//span[@class="matchOrderText ng-binding ng-scope"]')
for i in name:
    if i.text is None:
        title.append('--')
    else:
        title.append(i.text)

# %%
name=driver.find_elements_by_xpath('//span[@class="ng-binding"]')
for i in name:
    if i.text is None:
        series.append('--')
    else:
        series.append(i.text)

# %%
name=driver.find_elements_by_xpath('//div[@class="fix-place ng-binding ng-scope"]')
for i in name:
    if i.text is None:
        place.append('--')
    else:
        place.append(i.text)

# %%
dt=driver.find_elements_by_xpath('//div[@class="match-card-left match-schedule"]')
for i in dt:
    if i.text is None:
        date.append('--')
    else:
        date.append(i.text)

# %%
dt=driver.find_elements_by_xpath('//div[@class="match-card-right match-schedule "]')
for i in dt:
    if i.text is None:
        time.append('--')
    else:
        time.append(i.text)

# %%
ODI=pd.DataFrame({'Title':title[:16],
                 'Series':series[:16],
                 'Place':place[:16],
                 'Date':date[:16],
                 'Time':time[:16]})
ODI
# Out:
#          Title                                      Series  \
# 0   2nd T20I -     SRI LANKA TOUR OF INDIA T20 SERIES 2022
# 1   3rd T20I -     SRI LANKA TOUR OF INDIA T20 SERIES 2022
# 2   1st Test -    SRI LANKA TOUR OF INDIA TEST SERIES 2022
# 3   2nd Test -                   ICC WOMENS WORLD CUP 2022
# 4   1st T20I -                   ICC WOMENS WORLD CUP 2022
# 5   2nd T20I -    SRI LANKA TOUR OF INDIA TEST SERIES 2022
# 6   3rd T20I -                   ICC WOMENS WORLD CUP 2022
# 7   4th T20I -                   ICC WOMENS WORLD CUP 2022
# 8   5th T20I -                   ICC WOMENS WORLD CUP 2022
# 9   2nd T20I -                   ICC WOMENS WORLD CUP 2022
# 10  3rd T20I -                   ICC WOMENS WORLD CUP 2022
# 11  1st Test -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 12  2nd Test -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 13  1st T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 14  2nd T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# ...

# %%
driver.close()

# %% [raw]
# 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
#lets first connect to webdriver
driver=webdriver.Chrome('chromedriver.exe')

# Opening the homepage 
Url = "https://www.guru99.com/"
driver.get(Url)

# %%
driver.find_element_by_xpath('//a[@title="Selenium"]').click()

# %%
driver.find_element_by_xpath('//a[@title="Selenium Exception Handling (Common Exceptions List)"]').click()

# %%
Name=[]
Description=[]

# %%
name=driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[1]')
for i in name:
    if i.text is None:
        Name.append('--')
    else:
        Name.append(i.text)

# %%
len(Name)
# Out:
# 41

# %%
Des=driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[2]')
for i in Des:
    if i.text is None:
        Description.append('--')
    else:
        Description.append(i.text)

# %%
len(Description)
# Out:
# 41

# %%
sele_excp_handling=pd.DataFrame({'Name':Name,
                                'Description':Description
                                })
sele_excp_handling
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %%
driver.close()

# %% [raw]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP
# D) GSDP
# E) Share
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
#lets first connect to webdriver
driver=webdriver.Chrome('chromedriver.exe')

# Opening the homepage 
Url = "http://statisticstimes.com/"
driver.get(Url)

# %%
driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/button').click()

# %%
india=driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
url=india.get_attribute('href')
url
# Out:
# 'https://www.statisticstimes.com/economy/india-statistics.php'

# %%
driver.get(url)

# %%
Rank=[]
State=[]
GSDP=[]
Share=[]
GDP=[]

# %%
driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a').click()

# %%
# extracting rank 
try:
    rank=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[1]")
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')

# %%
len(Rank)
# Out:
# 33

# %%
# extracting state
try:
    state=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[2]")
    for i in state:
        State.append(i.text)
except NoSuchElementException:
    State.append('-')

# %%
len(State)
# Out:
# 33

# %%
# extracting GSDP
try:
    page=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[3]")
    for i in page:
        GSDP.append(i.text)
except NoSuchElementException:
    GSDP.append('-')

# %%
len(GSDP)
# Out:
# 33

# %%
# extracting GSDP_
GSDP_=[]
try:
    page=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[4]")
    for i in page:
        GSDP_.append(i.text)
except NoSuchElementException:
    GSDP_.append('-')

# %%
len(GSDP)
# Out:
# 33

# %%
# extracting share
try:
    page=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[5]")
    for i in page:
        Share.append(i.text)
except NoSuchElementException:
    Share.append('-')

# %%
len(Share)
# Out:
# 33

# %%
# extracting GDP
try:
    page=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[6]")
    for i in page:
        GDP.append(i.text)
except NoSuchElementException:
    GDP.append('-')

# %%
len(GDP)
# Out:
# 33

# %%
India_Econony=pd.DataFrame({'Rank':Rank,
                            'State':State,
                           'GSDP(19-20)':GSDP,
                           'GSDP(18-19)':GSDP_,
                           'Share':Share,
                           'GDP($ billion)':GDP
                           })

# %%
India_Econony
# Out:
#    Rank                      State GSDP(19-20) GSDP(18-19)   Share  \
# 0     1                Maharashtra           -   2,632,792  13.94%
# 1     2                 Tamil Nadu   1,845,853   1,630,208   8.63%
# 2     3              Uttar Pradesh   1,687,818   1,584,764   8.39%
# 3     4                    Gujarat           -   1,502,899   7.96%
# 4     5                  Karnataka   1,631,977   1,493,127   7.91%
# 5     6                West Bengal   1,253,832   1,089,898   5.77%
# 6     7                  Rajasthan   1,020,989     942,586   4.99%
# 7     8             Andhra Pradesh     972,782     862,957   4.57%
# 8     9                  Telangana     969,604     861,031   4.56%
# 9    10             Madhya Pradesh     906,672     809,592   4.29%
# 10   11                     Kerala           -     781,653   4.14%
# 11   12                      Delhi     856,112     774,870   4.10%
# 12   13                    Haryana     831,610     734,163   3.89%
# ...

# %%
driver.close()

# %% [raw]
# 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
#lets first connect to webdriver
driver=webdriver.Chrome('chromedriver.exe')

# Opening the homepage 
Url = "https://github.com/"
driver.get(Url)

# %%
driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details').click()

# %%
trending=driver.find_element_by_xpath("//html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
try:
    trending.click()
except ElementNotInteractableException:
    driver.get(trending.get_attribute('href'))

# %%
title=[]
description=[]
count=[]
language=[]

# %%
url=[]
try:
    url_=driver.find_elements_by_xpath('//h1[@class="h3 lh-condensed"]/a')
    for i in url_:
        url.append(i.get_attribute('href'))
except NoSuchElementException:
    url.append('--')   
len(url)
# Out:
# 25

# %%
try:
    page=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']")
    for i in page:
        title.append(i.text)
except NoSuchElementException:
    title.append('No details available')

# %%
try:
    Des=driver.find_elements_by_xpath("//p[@class='col-9 color-fg-muted my-1 pr-4']")
    for i in Des:
        description.append(i.text)     
except NoSuchElementException:
    description.append('--')

# %%
# contribution_count
for i in url:
    driver.get(i)
    try:
        counts=driver.find_element_by_xpath("//h2[@class='h4 mb-3']/a[contains(text(),'Contributors')]/span")
        count.append(counts.text)
    except NoSuchElementException: #handling no such element exception
        count.append('No details available')

# %%
 #language used    
l=[]
for i in url:
    driver.get(i)

    languages=driver.find_elements_by_xpath("//li[@class='d-inline']//a//span[1]")
    if languages:    
        for i in languages:
            l.append(i.text)
    else:
        l.append('No languages used')
    language.append(l)

# %%
len(language),len(count),len(description),len(title)
# Out:
# (25, 25, 23, 25)

# %%
git_hub=pd.DataFrame({'Title':title[:23],
                     'Description':description[:23],
                      'Contribution_count':count[:23],
                      'Language_used':language[:23]
                    })
git_hub
# Out:
#                                    Title  \
# 0               louisyoungx / JD-SHOPPER
# 1             github / advisory-database
# 2                      netdata / netdata
# 3                   jrouwe / JoltPhysics
# 4   KumarRobotics / kr_autonomous_flight
# 5                  nusr / hacker-laws-zh
# 6       anderspitman / awesome-tunneling
# 7         labuladong / fucking-algorithm
# 8                 withfig / autocomplete
# 9                    commaai / openpilot
# 10                    planetscale / beam
# 11        KurtBestor / Hitomi-Downloader
# 12                 VoronDesign / Voron-2
# 13         vueComponent / ant-design-vue
# 14    SebLague / Geographical-Adventures
# 15                    tiangolo / fastapi
# 16                 H5-Dooring / dooringx
# 17                      facebook / folly
# 18                          YaoApp / yao
# 19               hasura / graphql-engine
# 20             skywind3000 / preserve-cd
# 21                  nkallen / plasticity
# ...

# %%
driver.close()

# %% [raw]
# 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
#lets first connect to webdriver
driver=webdriver.Chrome('chromedriver.exe')

# Opening the homepage 
Url = "https:/www.billboard.com/"
driver.get(Url)

# %%
driver.find_element_by_xpath("/html/body/div[4]/header/div[2]/div/nav/ul/li[1]/a").click()

# %%
#Make empy list
last_week_rank=[]
peak_pos=[]
weeks_on_board=[]

# %%
song_name=[]
try:
    names=driver.find_elements_by_xpath("//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']/li/h3")
    for i in names:
        song_name.append(i.text)
except NoSuchElementException:
    song_name.append('-')   
    
artist_name=[]
try:
    name=driver.find_elements_by_xpath("//li[@class='lrv-u-width-100p']/ul/li[1]/span")
    for i in name:
        artist_name.append(i.text)
except NoSuchElementException:
    artist_name.append('-')

# %%
rank=[]
try:
    name=driver.find_elements_by_xpath("//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
    for i in name:
        rank.append(i.text)
except NoSuchElementException:
    rank.append('-')
rank
# Out:
# ['4',
#  '2',
#  '57',
#  '',
#  '',
#  '',
#  '3',
#  '1',
#  '19',
#  '',
#  '',
#  '',
#  '7',
#  '4',
#  '13',
#  '',
#  '',
#  '',
#  '5',
#  '1',
#  '32',
#  '',
#  '',
#  '',
#  '6',
#  '5',
#  '15',
#  '',
#  '',
#  '',
#  '8',
#  '4',
#  '23',
#  '',
#  '',
#  '',
#  '9',
#  '8',
#  '21',
#  '',
#  '',
#  '',
#  '12',
#  '9',
#  '22',
#  '',
#  '',
#  '',
#  '11',
#  '7',
#  '6',
#  '',
#  '',
#  '',
#  '10',
#  '8',
#  '8',
#  '',
#  '',
#  '',
#  '14',
#  '7',
#  '24',
#  '',
#  '',
#  '',
#  '13',
#  '8',
#  '36',
#  '',
#  '',
#  '',
#  '15',
#  '2',
#  '34',
#  '',
#  '',
#  '',
#  '-',
#  '15',
#  '1',
#  '',
#  '',
#  '',
#  '17',
#  '2',
#  '67',
#  '',
#  '',
#  '',
#  '16',
#  '1',
#  '30',
#  '',
#  '',
#  '',
#  '18',
#  '1',
#  '59',
#  '',
#  '',
#  '',
#  '19',
#  '16',
#  '8',
#  '',
#  '',
#  '',
#  '-',
#  '20',
#  '1',
#  '',
#  '',
#  '',
#  '-',
#  '21',
#  '1',
#  '',
#  '',
#  '',
#  '21',
#  '6',
#  '15',
#  '',
#  '',
#  '',
#  '-',
#  '23',
#  '6',
# ...

# %%
rank1=[]
try:
    add_ = driver.find_elements_by_xpath("//span[@class='c-label  a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet']")
    for i in add_:
        rank1.append(i.text)
except NoSuchElementException:
    rank1.append('--')
    
rank1[:3]
# Out:
# ['1', '1', '8']

# %%
rank1.extend(rank)

# %%
rank1
# Out:
# ['1',
#  '1',
#  '8',
#  '',
#  '',
#  '',
#  '4',
#  '2',
#  '57',
#  '',
#  '',
#  '',
#  '3',
#  '1',
#  '19',
#  '',
#  '',
#  '',
#  '7',
#  '4',
#  '13',
#  '',
#  '',
#  '',
#  '5',
#  '1',
#  '32',
#  '',
#  '',
#  '',
#  '6',
#  '5',
#  '15',
#  '',
#  '',
#  '',
#  '8',
#  '4',
#  '23',
#  '',
#  '',
#  '',
#  '9',
#  '8',
#  '21',
#  '',
#  '',
#  '',
#  '12',
#  '9',
#  '22',
#  '',
#  '',
#  '',
#  '11',
#  '7',
#  '6',
#  '',
#  '',
#  '',
#  '10',
#  '8',
#  '8',
#  '',
#  '',
#  '',
#  '14',
#  '7',
#  '24',
#  '',
#  '',
#  '',
#  '13',
#  '8',
#  '36',
#  '',
#  '',
#  '',
#  '15',
#  '2',
#  '34',
#  '',
#  '',
#  '',
#  '-',
#  '15',
#  '1',
#  '',
#  '',
#  '',
#  '17',
#  '2',
#  '67',
#  '',
#  '',
#  '',
#  '16',
#  '1',
#  '30',
#  '',
#  '',
#  '',
#  '18',
#  '1',
#  '59',
#  '',
#  '',
#  '',
#  '19',
#  '16',
#  '8',
#  '',
#  '',
#  '',
#  '-',
#  '20',
#  '1',
#  '',
#  '',
#  '',
#  '-',
#  '21',
#  '1',
#  '',
#  '',
#  '',
#  '21',
#  '6',
#  '15',
# ...

# %%
for i in rank1:
    if i=='':
        rank1.remove(i)
        
rank1
# Out:
# ['1',
#  '1',
#  '8',
#  '4',
#  '2',
#  '57',
#  '3',
#  '1',
#  '19',
#  '7',
#  '4',
#  '13',
#  '5',
#  '1',
#  '32',
#  '6',
#  '5',
#  '15',
#  '8',
#  '4',
#  '23',
#  '9',
#  '8',
#  '21',
#  '12',
#  '9',
#  '22',
#  '11',
#  '7',
#  '6',
#  '10',
#  '8',
#  '8',
#  '14',
#  '7',
#  '24',
#  '13',
#  '8',
#  '36',
#  '15',
#  '2',
#  '34',
#  '-',
#  '15',
#  '1',
#  '17',
#  '2',
#  '67',
#  '16',
#  '1',
#  '30',
#  '18',
#  '1',
#  '59',
#  '19',
#  '16',
#  '8',
#  '-',
#  '20',
#  '1',
#  '-',
#  '21',
#  '1',
#  '21',
#  '6',
#  '15',
#  '-',
#  '23',
#  '6',
#  '20',
#  '20',
#  '7',
#  '28',
#  '25',
#  '17',
#  '29',
#  '26',
#  '29',
#  '31',
#  '27',
#  '13',
#  '24',
#  '7',
#  '11',
#  '23',
#  '5',
#  '13',
#  '25',
#  '1',
#  '40',
#  '27',
#  '4',
#  '24',
#  '2',
#  '2',
#  '2',
#  '47',
#  '33',
#  '19',
#  '-',
#  '34',
#  '1',
#  '22',
#  '5',
#  '15',
#  '26',
#  '26',
#  '22',
#  '-',
#  '23',
#  '21',
#  '38',
#  '32',
#  '31',
#  '35',
#  '22',
# ...

# %%
last_week_rank=rank1[0::3]
last_week_rank
# Out:
# ['1',
#  '4',
#  '3',
#  '7',
#  '5',
#  '6',
#  '8',
#  '9',
#  '12',
#  '11',
#  '10',
#  '14',
#  '13',
#  '15',
#  '-',
#  '17',
#  '16',
#  '18',
#  '19',
#  '-',
#  '-',
#  '21',
#  '-',
#  '20',
#  '28',
#  '29',
#  '31',
#  '24',
#  '23',
#  '25',
#  '27',
#  '2',
#  '47',
#  '-',
#  '22',
#  '26',
#  '-',
#  '38',
#  '35',
#  '-',
#  '36',
#  '33',
#  '39',
#  '30',
#  '37',
#  '-',
#  '42',
#  '49',
#  '34',
#  '41',
#  '48',
#  '32',
#  '46',
#  '51',
#  '58',
#  '54',
#  '53',
#  '57',
#  '59',
#  '61',
#  '56',
#  '62',
#  '55',
#  '69',
#  '60',
#  '45',
#  '52',
#  '',
#  '2',
#  '',
#  '19',
#  '',
#  '2',
#  '',
#  '3',
#  '',
#  '8',
#  '',
#  '1',
#  '',
#  '5',
#  '',
#  '20',
#  '',
#  '3',
#  '',
#  '3',
#  '',
#  '4',
#  '',
#  '5',
#  '',
#  '9',
#  '',
#  '5',
#  '',
#  '6',
#  '',
#  '1',
#  '',
#  '3',
#  '',
#  '3',
#  '',
#  '13',
#  '',
#  '12',
#  '',
#  '20',
#  '',
#  '1',
#  '',
#  '5',
#  '',
#  '3',
#  '',
#  '4',
#  '',
#  '6',
#  '',
#  '16',
# ...

# %%
peak_pos=rank1[1::3]
peak_pos
# Out:
# ['1',
#  '2',
#  '1',
#  '4',
#  '1',
#  '5',
#  '4',
#  '8',
#  '9',
#  '7',
#  '8',
#  '7',
#  '8',
#  '2',
#  '15',
#  '2',
#  '1',
#  '1',
#  '16',
#  '20',
#  '21',
#  '6',
#  '23',
#  '20',
#  '25',
#  '26',
#  '27',
#  '7',
#  '5',
#  '1',
#  '4',
#  '2',
#  '33',
#  '34',
#  '5',
#  '26',
#  '23',
#  '32',
#  '22',
#  '1',
#  '3',
#  '27',
#  '21',
#  '28',
#  '11',
#  '46',
#  '9',
#  '42',
#  '19',
#  '36',
#  '48',
#  '23',
#  '11',
#  '40',
#  '53',
#  '53',
#  '48',
#  '57',
#  '55',
#  '51',
#  '56',
#  '53',
#  '24',
#  '64',
#  '14',
#  '45',
#  '52',
#  '40',
#  '',
#  '64',
#  '',
#  '43',
#  '',
#  '63',
#  '',
#  '66',
#  '',
#  '-',
#  '',
#  '71',
#  '',
#  '65',
#  '',
#  '80',
#  '',
#  '82',
#  '',
#  '81',
#  '',
#  '67',
#  '',
#  '70',
#  '',
#  '75',
#  '',
#  '83',
#  '',
#  '-',
#  '',
#  '85',
#  '',
#  '91',
#  '',
#  '72',
#  '',
#  '79',
#  '',
#  '74',
#  '',
#  '-',
#  '',
#  '76',
#  '',
#  '93',
#  '',
#  '95',
#  '',
#  '90',
#  '',
#  '86',
# ...

# %%
weeks_on_board=rank1[2::3]
weeks_on_board
# Out:
# ['8',
#  '57',
#  '19',
#  '13',
#  '32',
#  '15',
#  '23',
#  '21',
#  '22',
#  '6',
#  '8',
#  '24',
#  '36',
#  '34',
#  '1',
#  '67',
#  '30',
#  '59',
#  '8',
#  '1',
#  '1',
#  '15',
#  '6',
#  '7',
#  '17',
#  '29',
#  '13',
#  '11',
#  '13',
#  '40',
#  '24',
#  '2',
#  '19',
#  '1',
#  '15',
#  '22',
#  '21',
#  '31',
#  '28',
#  '24',
#  '35',
#  '7',
#  '23',
#  '33',
#  '33',
#  '1',
#  '32',
#  '4',
#  '7',
#  '7',
#  '12',
#  '18',
#  '6',
#  '21',
#  '8',
#  '14',
#  '7',
#  '8',
#  '6',
#  '21',
#  '13',
#  '10',
#  '5',
#  '6',
#  '9',
#  '19',
#  '2',
#  '40',
#  '',
#  '17',
#  '',
#  '43',
#  '',
#  '51',
#  '',
#  '66',
#  '',
#  '73',
#  '',
#  '71',
#  '',
#  '61',
#  '',
#  '76',
#  '',
#  '57',
#  '',
#  '78',
#  '',
#  '67',
#  '',
#  '65',
#  '',
#  '71',
#  '',
#  '63',
#  '',
#  '83',
#  '',
#  '82',
#  '',
#  '85',
#  '',
#  '66',
#  '',
#  '58',
#  '',
#  '37',
#  '',
#  '89',
#  '',
#  '38',
#  '',
#  '91',
#  '',
#  '68',
#  '',
#  '90',
#  '',
# ...

# %%
len(weeks_on_board),len(peak_pos),len(last_week_rank)
# Out:
# (133, 133, 134)

# %%
billboard=pd.DataFrame({'Song Name':song_name[:100],
                         'Artist Name':artist_name[:100],
                         'Last_Week_Rank':last_week_rank[:100],
                        'Peak Rank':peak_pos[:100],
                         'Weeks On Board':weeks_on_board[:100]
                        })
billboard
# Out:
#                           Song Name  \
# 0         We Don't Talk About Bruno
# 1                        Heat Waves
# 2                        Easy On Me
# 3                           abcdefu
# 4                              Stay
# ..                              ...
# 95  All Too Well (Taylor's Version)
# 96       Come Back As A Country Boy
# 97                             Iffy
# 98                       Home Sweet
# 99                         Too Easy
#
#                                           Artist Name Last_Week_Rank  \
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...              1
# 1                                       Glass Animals              4
# 2                                               Adele              3
# 3                                               GAYLE              7
# 4                       The Kid LAROI & Justin Bieber              5
# ..                                                ...            ...
# ...

# %%
driver.close()

# %% [raw]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
#lets first connect to webdriver
driver=webdriver.Chrome('chromedriver.exe')

# Opening the homepage 
Url = "https://www.naukri.com/recruiters"
driver.get(Url)

# %%
#clicking button
search_job=driver.find_element_by_xpath('//input[@class="sugInp"]')
search_job.send_keys('Data science')

# %%
button=driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button')
button.click()

# %%
#Make empy list
Name=[]
Designation=[] 
Company=[] 
Skills=[] 
Location=[]

name = driver.find_elements_by_xpath('//span[@class="fl ellipsis"]')
for i in name:
    Name.append(i.text)
    
designation = driver.find_elements_by_xpath('//span[@class="ellipsis clr"]')
for i in designation:
    Designation.append(i.text)
    
company = driver.find_elements_by_xpath('//p[@class="highlightable"]/a[2]')
for i in company:
    Company.append(i.text)
    
skill = driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]')
for i in skill:
    Skills.append(i.text)
    
loc = driver.find_elements_by_xpath('//p[@class="highlightable"]/span[2]')
for i in loc:
    try:
        Location.append(i.text)
    except NoSuchElementException:        
        Location.append("---")

# %%
print(len(Name),len(Designation),len(Company),len(Skills),len(Location))
# Out:
# 50 50 50 50 48

# %%
# making DataFrame
Recruiters=pd.DataFrame({'Name':Name[:48],
                      'Designation':Designation[:48],
                     'company':Company[:48],
                      'skill':Skills[:48],
                      'Location':Location[:48]
                     })
Recruiters
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Sakshi Chhikara
# 11                                 Priyanka Akiri
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                             Mahesh Babu Channa
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# ...

# %%
driver.close()

# %% [raw]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
#lets first connect to webdriver
driver=webdriver.Chrome('chromedriver.exe')

# Opening the homepage 
Url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare//"
driver.get(Url)

# %%
#Make empy list
bookname=[]
authorname=[]
volumes=[]
publisher=[]
genre=[]

# %%
#scraping book name
name=driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in name:
    if i.text is None:
        bookname.append('--')
    else:
        bookname.append(i.text)

# %%
len(bookname)
# Out:
# 100

# %%
#scraping author name
name=driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in name:
    if i.text is None:
        authorname.append('--')
    else:
        authorname.append(i.text)

# %%
len(authorname)
# Out:
# 100

# %%
#scraping volumes
name=driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in name:
    if i.text is None:
        volumes.append('--')
    else:
        volumes.append(i.text)

# %%
len(volumes)
# Out:
# 100

# %%
#scraping publisher
name=driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in name:
    if i.text is None:
        publisher.append('--')
    else:
        publisher.append(i.text)

# %%
len(publisher)
# Out:
# 100

# %%
#scraping name
name=driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in name:
    if i.text is None:
        genre.append('--')
    else:
        genre.append(i.text)

# %%
len(genre)
# Out:
# 100

# %%
# making DataFrame
Novels=pd.DataFrame({'Book_Name':bookname[:100],
                      'Author_Name':authorname[:100],
                      'Volumes':volumes[:100],
                      'Publisher':publisher[:100],
                      'Genre':genre[:100]
                     })
Novels
# Out:
#                                             Book_Name       Author_Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#       Volumes        Publisher                        Genre
# ...

# %%
driver.close()

# %% [raw]
# 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
#lets first connect to webdriver
driver=webdriver.Chrome('chromedriver.exe')

# Opening the homepage
Url = "https://www.imdb.com/list/ls095964455/"
driver.get(Url)

# %%
#Make empy list
Name=[]
Year=[]
Genre=[]
Runtime=[]
Ratings=[]
Votes=[]

# %%
#scraping name
name=driver.find_elements_by_xpath('//h3[@class="lister-item-header"]/a')
for i in name:
    if i.text is None:
        Name.append('--')
    else:
        Name.append(i.text)

# %%
len(Name)
# Out:
# 100

# %%
#scraping year
yr=driver.find_elements_by_xpath('//span[@class="lister-item-year text-muted unbold"]')
for i in yr:
    if i.text is None:
        Year.append('--')
    else:
        Year.append(i.text)

# %%
len(Year)
# Out:
# 100

# %%
#scraping genre
genre=driver.find_elements_by_xpath('//span[@class="genre"]')
for i in genre:
    if i.text is None:
        Genre.append('--')
    else:
        Genre.append(i.text)

# %%
len(Genre)
# Out:
# 100

# %%
#scraping runtime
run=driver.find_elements_by_xpath('//span[@class="runtime"]')
for i in run:
    if i.text is None:
        Runtime.append('--')
    else:
        Runtime.append(i.text)

# %%
len(Runtime)
# Out:
# 100

# %%
#scraping rating
rate=driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]/span[2]')
for i in rate:
    if i.text is None:
        Ratings.append('--')
    else:
        Ratings.append(i.text)

# %%
len(Ratings)
# Out:
# 100

# %%
#scraping votes
vote=driver.find_elements_by_xpath('//span[@name="nv"]')
for i in vote:
    if i.text is None:
        Votes.append('--')
    else:
        Votes.append(i.text)

# %%
len(Votes)
# Out:
# 100

# %%
# making DataFrame
tv_show=pd.DataFrame({'Name':Name[:100],
                      'Year':Year[:100],
                      'Genre':Genre[:100],
                      'Runtime':Runtime[:100],
                      'Ratings':Ratings[:100],
                      'Votes':Votes[:100]
                     })
tv_show
# Out:
#                               Name         Year                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#     Runtime Ratings      Votes
# 0    57 min     9.2  1,955,848
# ...

# %%
driver.close()

# %% [raw]
# 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code

# %%
#lets first connect to webdriver
driver=webdriver.Chrome('chromedriver.exe')

# Opening the homepage of uci.edu
Url = "https://archive.ics.uci.edu/"
driver.get(Url)

# %%
page=driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/span/b/a') # lacating ShowAllDataset page
page.click()                                                                 # clicking the ShowAllDataset page for details

# %%
uci_url=[]
url=driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[1]/td[1]/p/a')
for i in url:
    uci_url.append(i.get_attribute('href'))

# %%
#Make empy list
Name=[]
Type=[]
Task=[]
Attribute_type=[]
Instances=[]
Attribute=[]
Year=[]

# %%
#scraping dataset name
name=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b')
for i in name:
    if i.text is None:
        Name.append('--')
    else:
        Name.append(i.text)

# %%
len(Name)
# Out:
# 622

# %%
# Scraping dataset type
type=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[2]')
for i in type:
    if i.text is None:
        Type.append('--')
    else:
        Type.append(i.text)

# %%
len(Type)
# Out:
# 623

# %%
# Scraping task
task=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[3]')
for i in task:
    if i.text is None:
        Task.append('--')
    else:
        Task.append(i.text)

# %%
len(Task)
# Out:
# 623

# %%
# Scraping Attribute_type
type=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[4]')
for i in type:
    if i.text is None:
        Attribute_type.append('--')
    else:
        Attribute_type.append(i.text)

# %%
len(Attribute_type)
# Out:
# 623

# %%
# Scraping Instances
instances=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[5]')
for i in instances:                           
    if i.text is None:                                          
        Instances.append('--')
    else:
        Instances.append(i.text)

# %%
len(Instances)
# Out:
# 623

# %%
# Scraping Attribute
attri=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[6]')
for i in attri:                           
    if i.text is None:                                          
        Attribute.append('--')
    else:
        Attribute.append(i.text)

# %%
len(Attribute)
# Out:
# 623

# %%
# Scraping Year
yr=driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[7]')
for i in yr:                           
    if i.text is None:                                          
        Year.append('--')
    else:
        Year.append(i.text)

# %%
len(Year)
# Out:
# 623

# %%
# making DataFrame
uci=pd.DataFrame({'Dataset_Name':Name[:622],
                  'Dataset_Type':Type[:622],
                  'Task':Task[:622],
                  'Attribute_type':Attribute_type[:622],
                  'Instances':Instances[:622],
                  'Attribute':Attribute[:622],
                  'Year':Year[:622]
                 })
uci
# Out:
#                                           Dataset_Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                    Dataset_Type                  Task  \
# 0                    Data Types          Default Task
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                 Multivariate        Classification
# ...

# %%
driver.close()
